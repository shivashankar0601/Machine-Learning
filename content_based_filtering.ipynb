# %%
import numpy as np
import numpy.random as rand
import pandas as pd
import os, json
import matplotlib.pyplot as plt
from random import randint
import pickle
from sklearn.preprocessing import MinMaxScaler 
from sklearn import model_selection
from sklearn.feature_extraction.text import TfidfVectorizer
import warnings
from sklearn.metrics.pairwise import cosine_similarity

# %%
warnings.filterwarnings("ignore")

# %%
#Get the final dataset from CNN
product_prop = pd.read_csv("dataset_from_cnn_all_final.csv")

# %%
product_prop
# Out:
#       product_id  category_id         bounding_box  occlusion  viewpoint  \
# 0         P00003           10    [1, 52, 467, 831]          1          1
# 1         P00004           10   [0, 113, 467, 623]          1          2
# 2         P00005           10    [1, 98, 467, 814]          1          1
# 3         P00006           10   [0, 324, 466, 831]          3          2
# 4         P00007           10  [23, 106, 430, 696]          1          1
# ...          ...          ...                  ...        ...        ...
# 11914     P29973            7   [98, 58, 403, 630]          1          1
# 11915     P29981            7    [65, 1, 395, 557]          2          3
# 11916     P29997            3    [0, 17, 467, 623]          1          1
# 11917     P29998            3     [0, 0, 463, 779]          1          2
# 11918     P29999            3     [0, 2, 467, 616]          1          1
#
#        zoom-in       image  pattern     color
# 0            2  000003.jpg    plain  Charcoal
# 1            2  000004.jpg  printed  Charcoal
# 2            2  000005.jpg  printed  Charcoal
# 3            2  000006.jpg    plain      Gray
# 4            1  000007.jpg    plain      Gray
# ...        ...         ...      ...       ...
# 11914        2  029973.jpg    plain  Charcoal
# 11915        2  029981.jpg    plain       Tan
# 11916        3  029997.jpg  printed      Gray
# 11917        2  029998.jpg  printed      Gray
# 11918        2  029999.jpg  printed      Gray
#
# [11919 rows x 9 columns]

# %%
#Replacing category flag with values

conditions = [
    (product_prop['category_id'] == 0),
    (product_prop['category_id'] == 1),
    (product_prop['category_id'] == 2),
    (product_prop['category_id'] == 3),
    (product_prop['category_id'] == 4),
    (product_prop['category_id'] == 5),
    (product_prop['category_id'] == 6),
    (product_prop['category_id'] == 7),
    (product_prop['category_id'] == 8),
    (product_prop['category_id'] == 9),
    (product_prop['category_id'] == 10),
    (product_prop['category_id'] == 11),
    (product_prop['category_id'] == 12)
    ]

values = ['short_sleeve_top', 'long_sleeve_top', 'short_sleeve_outwear', 'long_sleeve_outwear','vest','sling',
          'shorts','trousers','skirt','short_sleeve_dress','long_sleeve_dress','vest_dress','sling_dress']

product_prop['category_name'] = np.select(conditions, values)

# %%
#Replacing occlusion flag with values

conditions = [
    (product_prop['occlusion'] == 1),
    (product_prop['occlusion'] == 2),
    (product_prop['occlusion'] == 3)
    ]

values = ['slight', 'medium', 'heavy']

product_prop['occlusion_type'] = np.select(conditions, values)

# %%
#Replacing zoom-in flag with values

conditions = [
    (product_prop['zoom-in'] == 1),
    (product_prop['zoom-in'] == 2),
    (product_prop['zoom-in'] == 3)
    ]

values = ['no', 'medium', 'heavy']

product_prop['zoom_in_type'] = np.select(conditions, values)

# %%
#Replacing viewpoint flag with values

conditions = [
    (product_prop['viewpoint'] == 1),
    (product_prop['viewpoint'] == 2),
    (product_prop['viewpoint'] == 3)
    ]

values = ['no', 'frontal', 'side_back']

product_prop['viewpoint_type'] = np.select(conditions, values)

# %%
product_prop
# Out:
#       product_id  category_id         bounding_box  occlusion  viewpoint  \
# 0         P00003           10    [1, 52, 467, 831]          1          1
# 1         P00004           10   [0, 113, 467, 623]          1          2
# 2         P00005           10    [1, 98, 467, 814]          1          1
# 3         P00006           10   [0, 324, 466, 831]          3          2
# 4         P00007           10  [23, 106, 430, 696]          1          1
# ...          ...          ...                  ...        ...        ...
# 11914     P29973            7   [98, 58, 403, 630]          1          1
# 11915     P29981            7    [65, 1, 395, 557]          2          3
# 11916     P29997            3    [0, 17, 467, 623]          1          1
# 11917     P29998            3     [0, 0, 463, 779]          1          2
# 11918     P29999            3     [0, 2, 467, 616]          1          1
#
#        zoom-in       image  pattern     color        category_name  \
# 0            2  000003.jpg    plain  Charcoal    long_sleeve_dress
# 1            2  000004.jpg  printed  Charcoal    long_sleeve_dress
# 2            2  000005.jpg  printed  Charcoal    long_sleeve_dress
# 3            2  000006.jpg    plain      Gray    long_sleeve_dress
# 4            1  000007.jpg    plain      Gray    long_sleeve_dress
# ...        ...         ...      ...       ...                  ...
# 11914        2  029973.jpg    plain  Charcoal             trousers
# 11915        2  029981.jpg    plain       Tan             trousers
# 11916        3  029997.jpg  printed      Gray  long_sleeve_outwear
# 11917        2  029998.jpg  printed      Gray  long_sleeve_outwear
# 11918        2  029999.jpg  printed      Gray  long_sleeve_outwear
#
#       occlusion_type zoom_in_type viewpoint_type
# 0             slight       medium             no
# 1             slight       medium        frontal
# 2             slight       medium             no
# 3              heavy       medium        frontal
# 4             slight           no             no
# ...              ...          ...            ...
# 11914         slight       medium             no
# 11915         medium       medium      side_back
# 11916         slight        heavy             no
# 11917         slight       medium        frontal
# 11918         slight       medium             no
#
# [11919 rows x 13 columns]

# %%
#Remove unnecessary columns
product_prop = product_prop.drop(['category_id','bounding_box','image','occlusion',
                     'viewpoint','zoom-in'],axis=1)

# %%
product_prop
# Out:
#       product_id  pattern     color        category_name occlusion_type  \
# 0         P00003    plain  Charcoal    long_sleeve_dress         slight
# 1         P00004  printed  Charcoal    long_sleeve_dress         slight
# 2         P00005  printed  Charcoal    long_sleeve_dress         slight
# 3         P00006    plain      Gray    long_sleeve_dress          heavy
# 4         P00007    plain      Gray    long_sleeve_dress         slight
# ...          ...      ...       ...                  ...            ...
# 11914     P29973    plain  Charcoal             trousers         slight
# 11915     P29981    plain       Tan             trousers         medium
# 11916     P29997  printed      Gray  long_sleeve_outwear         slight
# 11917     P29998  printed      Gray  long_sleeve_outwear         slight
# 11918     P29999  printed      Gray  long_sleeve_outwear         slight
#
#       zoom_in_type viewpoint_type
# 0           medium             no
# 1           medium        frontal
# 2           medium             no
# 3           medium        frontal
# 4               no             no
# ...            ...            ...
# 11914       medium             no
# 11915       medium      side_back
# 11916        heavy             no
# 11917       medium        frontal
# 11918       medium             no
#
# [11919 rows x 7 columns]

# %%
#this function creates users id's and associate the products randomly using normal distribution
# to the user based on a hyperparameter that is passed to this function.
# It also creates product reviews based on random normal distribution

#ppu: products per user, pc: products count
def associateUsersProducts(users,pc,ppu):
    dataset = {'user_id':list(),'product_ids':list(),'product_reviews':list(),'products_count':list()}
    
    # creating users
    length = len(str(users))
    for i in range(1,users+1):
        dataset['user_id'].append("U"+str(i).zfill(length))
    
    # creating products
    products = list(product_prop['product_id'].unique())
    products_list = products[0:250]
    
#     products_list = list()
#     length = 5 #len(str(pc)) # as per siddharth code, I am changing my code to match the product id's
#     for i in range(1,pc+1):
#         products_list.append("P"+str(i).zfill(length))

    # assigning products to users with randomly generated ratings
    min_rating = 1
    max_rating = 5 
    for i in range(users):
        total_products_count = rand.randint(1,ppu+1)
        dataset['product_ids'].append(
            [ products_list[x] for x in rand.randint(
                0,
                len(products_list),
                total_products_count
            ).tolist() ]
        )
        
        # dataset['product_reviews'].append(rand.randint(min_rating,max_rating+1,total_products_count))
        
        #a randomly generated value using normal distribution whose value will range from (MEAN - 2 x STD) <= value <= (MEAN + 2 x STD)
        # since the values can be 0 and our ratings should not be 0, we add 1 as minimum and since we are adding 1 as minmu, I am reducing the modulo to 4
        dataset['product_reviews'].append([round(x) for x in abs(1+np.random.normal(0,2.5,total_products_count)%4)])
        
        dataset['products_count'].append(total_products_count)
        
    return dataset

# %%
#parameters are: users count, products count, how many products to each user
dataset = associateUsersProducts(100,10000,80)

# %%
data = pd.DataFrame(dataset)
data
# Out:
#    user_id                                        product_ids  \
# 0     U001  [P00715, P00265, P00237, P00524, P00588, P0032...
# 1     U002  [P00216, P00006, P00229, P00423, P00711, P0033...
# 2     U003  [P00457, P00165, P00438, P00430, P00464, P0022...
# 3     U004  [P00010, P00271, P00711, P00409, P00272, P0027...
# 4     U005  [P00393, P00511, P00217, P00394, P00566, P0016...
# ..     ...                                                ...
# 95    U096  [P00523, P00168, P00459, P00101, P00514, P0054...
# 96    U097  [P00358, P00163, P00144, P00151, P00393, P0003...
# 97    U098  [P00010, P00008, P00365, P00427, P00271, P0041...
# 98    U099  [P00409, P00451, P00154, P00589, P00450, P0042...
# 99    U100  [P00475, P00512, P00422, P00084, P00297, P0008...
#
#                                       product_reviews  products_count
# 0   [4, 4, 1, 5, 3, 5, 2, 3, 3, 2, 3, 1, 3, 4, 4, ...              73
# 1   [1, 3, 2, 2, 2, 2, 1, 2, 3, 3, 4, 4, 5, 1, 3, ...              22
# 2    [4, 5, 5, 4, 4, 4, 5, 2, 1, 1, 5, 2, 4, 4, 4, 2]              16
# 3   [4, 4, 2, 5, 3, 4, 1, 5, 5, 1, 5, 3, 1, 2, 1, ...              78
# 4   [3, 1, 2, 4, 3, 4, 3, 4, 4, 4, 2, 2, 2, 2, 2, ...              23
# ..                                                ...             ...
# 95  [4, 2, 5, 4, 4, 4, 4, 3, 2, 5, 4, 3, 5, 2, 5, ...              77
# 96                           [3, 4, 5, 3, 4, 2, 4, 4]               8
# 97  [4, 1, 2, 1, 1, 3, 4, 2, 4, 4, 2, 2, 4, 4, 1, ...              49
# 98               [3, 5, 4, 4, 2, 2, 2, 3, 4, 3, 2, 3]              12
# 99  [4, 2, 4, 2, 2, 5, 4, 5, 1, 1, 5, 1, 2, 2, 2, ...              66
#
# [100 rows x 4 columns]

# %%
#Saving as pickle file to use it anytime later
data.to_pickle('user_preference_all.pkl')

# %%
user_preference = pd.read_pickle('user_preference_all.pkl')
print(type(user_preference))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#Converting the dataframe to long form
user_preference = user_preference.apply(pd.Series.explode).reset_index()

# %%
user_preference
# Out:
#       index user_id product_ids product_reviews  products_count
# 0         0    U001      P00715               4              73
# 1         0    U001      P00265               4              73
# 2         0    U001      P00237               1              73
# 3         0    U001      P00524               5              73
# 4         0    U001      P00588               3              73
# ...     ...     ...         ...             ...             ...
# 3948     99    U100      P00433               3              66
# 3949     99    U100      P00003               3              66
# 3950     99    U100      P00624               4              66
# 3951     99    U100      P00440               3              66
# 3952     99    U100      P00169               1              66
#
# [3953 rows x 5 columns]

# %%
user_preference = user_preference.drop_duplicates(subset=['user_id', 'product_ids'], keep='first')

# %%
user_preference = user_preference.rename(columns={"product_ids": "product_id"})

# %%
#Adding other attributes like pattern, color etc
cbf_df = user_preference.merge(product_prop,how ="left",on = "product_id")

# %%
cbf_df
# Out:
#       index user_id product_id product_reviews  products_count  pattern  \
# 0         0    U001     P00715               4              73    plain
# 1         0    U001     P00265               4              73    plain
# 2         0    U001     P00237               1              73    plain
# 3         0    U001     P00524               5              73  printed
# 4         0    U001     P00588               3              73    plain
# ...     ...     ...        ...             ...             ...      ...
# 3542     99    U100     P00534               2              66    plain
# 3543     99    U100     P00433               3              66    plain
# 3544     99    U100     P00003               3              66    plain
# 3545     99    U100     P00624               4              66  printed
# 3546     99    U100     P00440               3              66    plain
#
#          color      category_name occlusion_type zoom_in_type viewpoint_type
# 0       Silver  long_sleeve_dress         slight           no        frontal
# 1       Silver  long_sleeve_dress         medium           no        frontal
# 2         Gray    long_sleeve_top         medium        heavy        frontal
# 3       Silver         vest_dress         medium       medium        frontal
# 4         Gray    long_sleeve_top         slight           no             no
# ...        ...                ...            ...          ...            ...
# 3542  Charcoal           trousers         medium           no        frontal
# 3543    Silver   short_sleeve_top         slight       medium        frontal
# 3544  Charcoal  long_sleeve_dress         slight       medium             no
# 3545      Gray             shorts         slight       medium        frontal
# 3546       Tan   short_sleeve_top         slight       medium             no
#
# [3547 rows x 11 columns]

# %%
#Remove unnecessary columns
cbf_df = cbf_df.drop(['products_count','index'],axis=1)

# %%
cbf_df
# Out:
#      user_id product_id product_reviews  pattern     color      category_name  \
# 0       U001     P00715               4    plain    Silver  long_sleeve_dress
# 1       U001     P00265               4    plain    Silver  long_sleeve_dress
# 2       U001     P00237               1    plain      Gray    long_sleeve_top
# 3       U001     P00524               5  printed    Silver         vest_dress
# 4       U001     P00588               3    plain      Gray    long_sleeve_top
# ...      ...        ...             ...      ...       ...                ...
# 3542    U100     P00534               2    plain  Charcoal           trousers
# 3543    U100     P00433               3    plain    Silver   short_sleeve_top
# 3544    U100     P00003               3    plain  Charcoal  long_sleeve_dress
# 3545    U100     P00624               4  printed      Gray             shorts
# 3546    U100     P00440               3    plain       Tan   short_sleeve_top
#
#      occlusion_type zoom_in_type viewpoint_type
# 0            slight           no        frontal
# 1            medium           no        frontal
# 2            medium        heavy        frontal
# 3            medium       medium        frontal
# 4            slight           no             no
# ...             ...          ...            ...
# 3542         medium           no        frontal
# 3543         slight       medium        frontal
# 3544         slight       medium             no
# 3545         slight       medium        frontal
# 3546         slight       medium             no
#
# [3547 rows x 9 columns]

# %%
#Standardizing ratings so that it can be easy for comparision with predicted ratings later
min_max = MinMaxScaler(feature_range = (0.1,1))
min_max.fit(cbf_df['product_reviews'].values.reshape(-1,1))
cbf_df['standardized_rating'] = min_max.transform(cbf_df['product_reviews'].values.reshape(-1,1))

# %%
print(np.unique(cbf_df[['product_reviews', 'standardized_rating']].values))
# Out:
# [0.1 0.325 0.55 0.775 1.0 2 3 4 5]

# %% [markdown]
# **Build CBF on pattern,color and category**

# %%
#Step 1: Build product matrix on patterns
pattern_product = cbf_df[['product_id','pattern']]
pattern_product = pattern_product.sort_values(by='product_id')

# %%
pattern_product = pattern_product.drop_duplicates(subset=['product_id','pattern'], keep='first')

# %%
pattern_product
# Out:
#      product_id  pattern
# 1169     P00003    plain
# 2539     P00004  printed
# 1972     P00005  printed
# 244      P00006    plain
# 2004     P00007    plain
# ...         ...      ...
# 502      P00712    plain
# 840      P00713  printed
# 2581     P00714  printed
# 347      P00715    plain
# 2777     P00716    plain
#
# [250 rows x 2 columns]

# %%
#As patterns are strings, using TFIDF to convert them to usable values
tfidf = TfidfVectorizer()
tfidf_fit = tfidf.fit_transform(list(pattern_product['pattern']))

# %%
cols = tfidf.get_feature_names()

# %%
#Adding a small number (0.01) to avoid zeros
pattern_prod_matrix = (pd.DataFrame(tfidf_fit.toarray().round(3), 
                                   index=[i for i in pattern_product['product_id']], columns=cols))+0.01

# %%
pattern_prod_matrix
# Out:
#         plain  printed  stripes
# P00003   1.01     0.01     0.01
# P00004   0.01     1.01     0.01
# P00005   0.01     1.01     0.01
# P00006   1.01     0.01     0.01
# P00007   1.01     0.01     0.01
# ...       ...      ...      ...
# P00712   1.01     0.01     0.01
# P00713   0.01     1.01     0.01
# P00714   0.01     1.01     0.01
# P00715   1.01     0.01     0.01
# P00716   1.01     0.01     0.01
#
# [250 rows x 3 columns]

# %%
#Step 2: Build product matrix on color
color_product = cbf_df[['product_id','color']]
color_product = color_product.sort_values(by='product_id')

# %%
color_product
# Out:
#      product_id     color
# 1169     P00003  Charcoal
# 1592     P00003  Charcoal
# 1135     P00003  Charcoal
# 1979     P00003  Charcoal
# 3544     P00003  Charcoal
# ...         ...       ...
# 1888     P00716  Charcoal
# 1922     P00716  Charcoal
# 2527     P00716  Charcoal
# 2323     P00716  Charcoal
# 155      P00716  Charcoal
#
# [3547 rows x 2 columns]

# %%
color_product = color_product.drop_duplicates(subset=['product_id','color'], keep='first')

# %%
#As colors are strings, using TFIDF to convert them to usable values
tfidf = TfidfVectorizer()
tfidf_fit_1 = tfidf.fit_transform(list(color_product['color']))

# %%
cols_1 = tfidf.get_feature_names()
cols_1
# Out:
# ['bronze',
#  'brown',
#  'charcoal',
#  'coral',
#  'gray',
#  'lavender',
#  'pink',
#  'rust',
#  'silver',
#  'tan']

# %%
#Adding a small number (0.01) to avoid zeros
color_prod_matrix = (pd.DataFrame(tfidf_fit_1.toarray().round(3), 
                                   index=[i for i in color_product['product_id']], columns=cols_1))+0.01

# %%
color_prod_matrix
# Out:
#         bronze  brown  charcoal  coral  gray  lavender  pink  rust  silver  \
# P00003    0.01   0.01      1.01   0.01  0.01      0.01  0.01  0.01    0.01
# P00004    0.01   0.01      1.01   0.01  0.01      0.01  0.01  0.01    0.01
# P00005    0.01   0.01      1.01   0.01  0.01      0.01  0.01  0.01    0.01
# P00006    0.01   0.01      0.01   0.01  1.01      0.01  0.01  0.01    0.01
# P00007    0.01   0.01      0.01   0.01  1.01      0.01  0.01  0.01    0.01
# ...        ...    ...       ...    ...   ...       ...   ...   ...     ...
# P00712    0.01   0.01      0.01   0.01  0.01      0.01  0.01  0.01    1.01
# P00713    0.01   0.01      0.01   0.01  0.01      0.01  0.01  0.01    1.01
# P00714    0.01   0.01      0.01   0.01  0.01      0.01  0.01  0.01    1.01
# P00715    0.01   0.01      0.01   0.01  0.01      0.01  0.01  0.01    1.01
# P00716    0.01   0.01      1.01   0.01  0.01      0.01  0.01  0.01    0.01
#
#          tan
# P00003  0.01
# P00004  0.01
# P00005  0.01
# P00006  0.01
# P00007  0.01
# ...      ...
# P00712  0.01
# P00713  0.01
# P00714  0.01
# P00715  0.01
# P00716  0.01
#
# [250 rows x 10 columns]

# %%
#Step 3: Build product matrix on category
category_product = cbf_df[['product_id','category_name']]
category_product = category_product.sort_values(by='product_id')

# %%
category_product
# Out:
#      product_id      category_name
# 1169     P00003  long_sleeve_dress
# 1592     P00003  long_sleeve_dress
# 1135     P00003  long_sleeve_dress
# 1979     P00003  long_sleeve_dress
# 3544     P00003  long_sleeve_dress
# ...         ...                ...
# 1888     P00716  long_sleeve_dress
# 1922     P00716  long_sleeve_dress
# 2527     P00716  long_sleeve_dress
# 2323     P00716  long_sleeve_dress
# 155      P00716  long_sleeve_dress
#
# [3547 rows x 2 columns]

# %%
category_product = category_product.drop_duplicates(subset=['product_id','category_name'], keep='first')

# %%
#As categories are strings, using TFIDF to convert them to usable values
tfidf = TfidfVectorizer()
tfidf_fit_2 = tfidf.fit_transform(list(category_product['category_name']))

# %%
cols_2 = tfidf.get_feature_names()
cols_2
# Out:
# ['long_sleeve_dress',
#  'long_sleeve_outwear',
#  'long_sleeve_top',
#  'short_sleeve_dress',
#  'short_sleeve_top',
#  'shorts',
#  'trousers',
#  'vest',
#  'vest_dress']

# %%
#Adding a small number (0.01) to avoid zeros
category_prod_matrix = (pd.DataFrame(tfidf_fit_2.toarray().round(3), 
                                   index=[i for i in category_product['product_id']], columns=cols_2))+0.01

# %%
category_prod_matrix
# Out:
#         long_sleeve_dress  long_sleeve_outwear  long_sleeve_top  \
# P00003               1.01                 0.01             0.01
# P00004               1.01                 0.01             0.01
# P00005               1.01                 0.01             0.01
# P00006               1.01                 0.01             0.01
# P00007               1.01                 0.01             0.01
# ...                   ...                  ...              ...
# P00712               1.01                 0.01             0.01
# P00713               1.01                 0.01             0.01
# P00714               1.01                 0.01             0.01
# P00715               1.01                 0.01             0.01
# P00716               1.01                 0.01             0.01
#
#         short_sleeve_dress  short_sleeve_top  shorts  trousers  vest  \
# P00003                0.01              0.01    0.01      0.01  0.01
# P00004                0.01              0.01    0.01      0.01  0.01
# P00005                0.01              0.01    0.01      0.01  0.01
# P00006                0.01              0.01    0.01      0.01  0.01
# P00007                0.01              0.01    0.01      0.01  0.01
# ...                    ...               ...     ...       ...   ...
# P00712                0.01              0.01    0.01      0.01  0.01
# P00713                0.01              0.01    0.01      0.01  0.01
# P00714                0.01              0.01    0.01      0.01  0.01
# P00715                0.01              0.01    0.01      0.01  0.01
# P00716                0.01              0.01    0.01      0.01  0.01
#
#         vest_dress
# P00003        0.01
# P00004        0.01
# P00005        0.01
# P00006        0.01
# P00007        0.01
# ...            ...
# P00712        0.01
# P00713        0.01
# P00714        0.01
# P00715        0.01
# P00716        0.01
#
# [250 rows x 9 columns]

# %% [markdown]
# Finding cosine similarity between each attribute for all products

# %%
cosine_sim_matrix_pattern = pd.DataFrame(cosine_similarity(pattern_prod_matrix.values),
                                  columns=pattern_product['product_id'],index=pattern_product['product_id'])

# %%
cosine_sim_matrix_pattern
# Out:
# product_id    P00003    P00004    P00005    P00006    P00007    P00008  \
# product_id
# P00003      1.000000  0.019896  0.019896  1.000000  1.000000  0.019896
# P00004      0.019896  1.000000  1.000000  0.019896  0.019896  1.000000
# P00005      0.019896  1.000000  1.000000  0.019896  0.019896  1.000000
# P00006      1.000000  0.019896  0.019896  1.000000  1.000000  0.019896
# P00007      1.000000  0.019896  0.019896  1.000000  1.000000  0.019896
# ...              ...       ...       ...       ...       ...       ...
# P00712      1.000000  0.019896  0.019896  1.000000  1.000000  0.019896
# P00713      0.019896  1.000000  1.000000  0.019896  0.019896  1.000000
# P00714      0.019896  1.000000  1.000000  0.019896  0.019896  1.000000
# P00715      1.000000  0.019896  0.019896  1.000000  1.000000  0.019896
# P00716      1.000000  0.019896  0.019896  1.000000  1.000000  0.019896
#
# product_id    P00009    P00010    P00015    P00020  ...    P00686    P00688  \
# product_id                                          ...
# P00003      1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# P00004      0.019896  0.019896  0.019896  0.019896  ...  0.019896  0.019896
# P00005      0.019896  0.019896  0.019896  0.019896  ...  0.019896  0.019896
# P00006      1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# P00007      1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# ...              ...       ...       ...       ...  ...       ...       ...
# P00712      1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# P00713      0.019896  0.019896  0.019896  0.019896  ...  0.019896  0.019896
# P00714      0.019896  0.019896  0.019896  0.019896  ...  0.019896  0.019896
# P00715      1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# P00716      1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
#
# product_id    P00690    P00693    P00711    P00712    P00713    P00714  \
# product_id
# P00003      1.000000  1.000000  1.000000  1.000000  0.019896  0.019896
# P00004      0.019896  0.019896  0.019896  0.019896  1.000000  1.000000
# P00005      0.019896  0.019896  0.019896  0.019896  1.000000  1.000000
# P00716      0.020472  0.020472  1.000000  0.020568  0.000409  0.000409
#
# product_id    P00715    P00716
# product_id
# P00003      0.020568  1.000000
# P00004      0.000409  0.019896
# P00005      0.000409  0.019896
# P00006      0.020568  0.020568
# P00007      0.020568  0.020568
# ...              ...       ...
# P00712      1.000000  0.020568
# P00713      0.019896  0.000409
# P00714      0.019896  0.000409
# P00715      1.000000  0.020568
# P00716      0.020568  1.000000
#
# [250 rows x 250 columns]

# %%
#Creating the user*product matrix with ratings

user_prod_matrix = pd.pivot(data = cbf_df, index = 'user_id', columns = 'product_id', values = 'product_reviews')

# %%
#user_prod_matrix
#There are NaN values for products for which ratings does not exist. Fill them with 0s
user_prod_matrix = user_prod_matrix.fillna(0)

# %%
user_prod_matrix
# Out:
# product_id  P00003  P00004  P00005  P00006  P00007  P00008  P00009  P00010  \
# user_id
# U001             0       0       0       0       4       0       0       0
# U002             0       0       0       3       0       0       3       4
# U003             0       0       0       0       0       0       0       0
# U004             0       4       0       0       0       4       0       4
# U005             0       0       0       0       0       0       0       0
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# U096             0       4       0       3       0       0       0       0
# U097             0       0       0       0       0       0       0       0
# U098             0       2       0       0       0       1       0       4
# U099             0       0       0       0       0       0       0       0
# U100             3       4       0       0       0       3       0       2
#
# product_id  P00015  P00020  ...  P00686  P00688  P00690  P00693  P00711  \
# user_id                     ...
# U001             0       0  ...       0       0       0       0       0
# U002             0       0  ...       4       0       0       0       2
# U003             0       0  ...       0       0       0       0       0
# U004             0       0  ...       4       0       0       0       2
# U005             4       0  ...       0       0       0       0       0
# ...            ...     ...  ...     ...     ...     ...     ...     ...
# U096             0       2  ...       0       0       0       3       0
# U097             0       0  ...       0       0       0       0       0
# U098             3       0  ...       0       0       0       4       0
# U099             3       0  ...       0       0       0       0       0
# U100             0       2  ...       0       0       0       1       0
#
# product_id  P00712  P00713  P00714  P00715  P00716
# user_id
# U001             0       3       3       4       3
# U002             0       0       0       0       0
# U003             0       0       0       0       0
# U004             2       0       0       2       2
# U005             0       0       0       0       0
# ...            ...     ...     ...     ...     ...
# U096             0       4       2       0       0
# U097             0       0       0       0       0
# U098             0       0       4       0       0
# U099             0       0       0       0       0
# U100             0       0       0       0       0
#
# [100 rows x 250 columns]

# %%
#Predicting ratings based on all attributes

weighted_ratings = user_prod_matrix.dot(final_similarity_matrix)

# %%
weighted_ratings
# Out:
# product_id    P00003    P00004    P00005    P00006    P00007    P00008  \
# user_id
# U001        9.150738  0.605544  0.605544  9.633959  9.633959  0.715373
# U002        2.622891  0.118399  0.118399  7.162323  7.162323  0.369061
# U003        0.444072  0.133399  0.133399  6.378822  6.378822  0.151262
# U004        5.230228  4.444330  4.444330  6.817575  6.817575  4.796602
# U005        0.160136  0.237151  0.237151  2.422957  2.422957  0.442517
# ...              ...       ...       ...       ...       ...       ...
# U096        1.521820  4.864002  4.864002  9.558584  9.558584  5.063988
# U097        0.170515  0.066889  0.066889  0.271568  0.271568  0.108986
# U098        3.052458  2.455513  2.455513  2.851714  2.851714  1.432388
# U099        0.091632  0.004769  0.004769  0.335037  0.335037  0.149914
# U100        6.932981  4.558381  4.558381  2.118653  2.118653  5.601984
#
# product_id    P00009    P00010     P00015     P00020  ...     P00686  \
# user_id                                               ...
# U001        0.705696  0.705696   7.923670   7.923670  ...   7.602285
# U002        7.378699  7.378699   0.405561   0.405561  ...   4.440116
# U003        0.302642  0.302642   5.278012   5.278012  ...   0.282495
# U004        4.831123  4.831123  15.301041  15.301041  ...   7.704456
# U005        0.158933  0.158933   4.455044   4.455044  ...   0.075940
# ...              ...       ...        ...        ...  ...        ...
# U096        3.612453  3.612453   5.124430   5.124430  ...  11.565549
# U097        0.170515  0.170515   0.271568   0.271568  ...   0.251103
# U098        8.725864  8.725864   5.666065   5.666065  ...   4.667526
# U099        0.153676  0.153676   3.351576   3.351576  ...   0.131926
# U100        4.569610  4.569610   6.451860   6.451860  ...   3.590082
#
# product_id     P00688     P00690     P00693    P00711     P00712     P00713  \
# user_id
# U001         7.602285   7.602285   7.602285  9.150738  30.113060  12.771143
# U002         4.440116   4.440116   4.440116  2.622891   0.421887   2.012653
# U003         0.282495   0.282495   0.282495  0.444072   6.338156   1.129497
# U004         7.704456   7.704456   7.704456  5.230228  26.855211   6.752499
# U005         0.075940   0.075940   0.075940  0.160136   2.393839   9.052904
# ...               ...        ...        ...       ...        ...        ...
# U096        11.565549  11.565549  11.565549  1.521820  34.970792  18.016563
# U097         0.251103   0.251103   0.251103  0.170515   0.008910   0.003545
# U098         4.667526   4.667526   4.667526  3.052458  18.535535   8.437400
# U099         0.131926   0.131926   0.131926  0.091632   0.151785   0.005966
# U100         3.590082   3.590082   3.590082  6.932981  21.781911   5.712602
#
# product_id     P00714     P00715    P00716
# user_id
# U001        12.771143  30.113060  9.150738
# U002         2.012653   0.421887  2.622891
# U003         1.129497   6.338156  0.444072
# U004         6.752499  26.855211  5.230228
# U005         9.052904   2.393839  0.160136
# ...               ...        ...       ...
# U096        18.016563  34.970792  1.521820
# U097         0.003545   0.008910  0.170515
# U098         8.437400  18.535535  3.052458
# U099         0.005966   0.151785  0.091632
# U100         5.712602  21.781911  6.932981
#
# [100 rows x 250 columns]

# %%
#Standardizing the weighted ratings

min_max = MinMaxScaler(feature_range = (0.1,1))
min_max.fit(weighted_ratings.values)
weighted_ratings = min_max.transform(weighted_ratings.values)

# %%
weighted_ratings
# Out:
# array([[0.67015194, 0.19575889, 0.19575889, ..., 0.73796948, 0.74981278,
#         0.67015194],
#        [0.26333301, 0.11871797, 0.11871797, ..., 0.20053828, 0.10910305,
#         0.26333301],
#        [0.12754789, 0.12109016, 0.12109016, ..., 0.15642097, 0.236771  ,
#         0.12754789],
#        ...,
#        [0.29010389, 0.48832784, 0.48832784, ..., 0.52148103, 0.49997985,
#         0.29010389],
#        [0.10558362, 0.10074766, 0.10074766, ..., 0.10029595, 0.10327448,
#         0.10558362],
#        [0.53194015, 0.82089228, 0.82089228, ..., 0.38536609, 0.57003382,
#         0.53194015]])

# %%
#Convert this array back to matrix form
weighted_ratings_df = pd.DataFrame(weighted_ratings,index=sorted(cbf_df['user_id'].unique()),
                                columns=sorted(cbf_df['product_id'].unique()))

# %%
# test = pd.melt(weighted_ratings, id_vars=sorted(cbf_df['user_id'].unique()),
#                                                 value_vars=sorted(cbf_df['product_id'].unique()))
weighted_ratings_df = weighted_ratings_df.stack().reset_index()

# %%
weighted_ratings_df = weighted_ratings_df.rename(columns={'level_0':'user_id','level_1':'product_id',
                                                  0:'predicted_rating'})

# %%
weighted_ratings_df
# Out:
#       user_id product_id  predicted_rating
# 0        U001     P00003          0.670152
# 1        U001     P00004          0.195759
# 2        U001     P00005          0.195759
# 3        U001     P00006          0.671890
# 4        U001     P00007          0.671890
# ...       ...        ...               ...
# 24995    U100     P00712          0.570034
# 24996    U100     P00713          0.385366
# 24997    U100     P00714          0.385366
# 24998    U100     P00715          0.570034
# 24999    U100     P00716          0.531940
#
# [25000 rows x 3 columns]

# %%
prod_attr = weighted_ratings_df.merge(product_prop,on=['product_id'],how='left')

# %%
prod_attr
# Out:
#       user_id product_id  predicted_rating  pattern     color  \
# 0        U001     P00003          0.670152    plain  Charcoal
# 1        U001     P00004          0.195759  printed  Charcoal
# 2        U001     P00005          0.195759  printed  Charcoal
# 3        U001     P00006          0.671890    plain      Gray
# 4        U001     P00007          0.671890    plain      Gray
# ...       ...        ...               ...      ...       ...
# 24995    U100     P00712          0.570034    plain    Silver
# 24996    U100     P00713          0.385366  printed    Silver
# 24997    U100     P00714          0.385366  printed    Silver
# 24998    U100     P00715          0.570034    plain    Silver
# 24999    U100     P00716          0.531940    plain  Charcoal
#
#            category_name occlusion_type zoom_in_type viewpoint_type
# 0      long_sleeve_dress         slight       medium             no
# 1      long_sleeve_dress         slight       medium        frontal
# 2      long_sleeve_dress         slight       medium             no
# 3      long_sleeve_dress          heavy       medium        frontal
# 4      long_sleeve_dress         slight           no             no
# ...                  ...            ...          ...            ...
# 24995  long_sleeve_dress         slight       medium      side_back
# 24996  long_sleeve_dress         slight           no        frontal
# 24997  long_sleeve_dress         slight           no        frontal
# 24998  long_sleeve_dress         slight           no        frontal
# 24999  long_sleeve_dress         slight           no        frontal
#
# [25000 rows x 9 columns]

# %%
prod_attr.sort_values(by=['predicted_rating'], inplace=True,ascending=False)

# %%
#Checking how ratings are being calculated for a user

# %%
user_037_pred = prod_attr[prod_attr['user_id']=="U037"]

# %%
user_037_act = cbf_df[cbf_df['user_id']=="U037"]

# %%
u037_merged = user_037_pred.merge(user_037_act,how='left',on=['user_id','product_id'])

# %%
#This u037_merged table contains predicted ratings for all products of the user U037

# %%
#The predicted_rating is standardized (between 0 and 1). standardized_rating is the standardized version 
#of product_reviews column. Note that if the product_reviews column is NaN, that means the user did not provide rating
#for that product. predicted_rating provides the corresponding rating that the user can possibly provide
u037_merged
# Out:
#     user_id product_id  predicted_rating pattern_x   color_x category_name_x  \
# 0      U037     P00524          1.000000   printed    Silver      vest_dress
# 1      U037     P00522          1.000000   printed    Silver      vest_dress
# 2      U037     P00160          1.000000   printed     Brown      vest_dress
# 3      U037     P00171          1.000000   printed    Silver      vest_dress
# 4      U037     P00173          1.000000   printed    Silver      vest_dress
# ..      ...        ...               ...       ...       ...             ...
# 245    U037     P00157          0.117687     plain  Charcoal      vest_dress
# 246    U037     P00147          0.117687     plain  Charcoal      vest_dress
# 247    U037     P00165          0.117687     plain  Charcoal      vest_dress
# 248    U037     P00167          0.117687     plain  Charcoal      vest_dress
# 249    U037     P00172          0.117687     plain  Charcoal      vest_dress
#
#     occlusion_type_x zoom_in_type_x viewpoint_type_x product_reviews  \
# 0             medium         medium          frontal               5
# 1             medium         medium        side_back               5
# 2             medium             no          frontal               4
# 3              heavy         medium          frontal               1
# 4              heavy             no          frontal               3
# ..               ...            ...              ...             ...
# 245           slight          heavy               no             NaN
# 246           slight             no        side_back             NaN
# 247           medium             no        side_back             NaN
# 248           slight             no          frontal             NaN
# 249           medium             no        side_back             NaN
#
#     pattern_y color_y category_name_y occlusion_type_y zoom_in_type_y  \
# 0     printed  Silver      vest_dress           medium         medium
# 1     printed  Silver      vest_dress           medium         medium
# 2     printed   Brown      vest_dress           medium             no
# 3     printed  Silver      vest_dress            heavy         medium
# 4     printed  Silver      vest_dress            heavy             no
# ..        ...     ...             ...              ...            ...
# 245       NaN     NaN             NaN              NaN            NaN
# 246       NaN     NaN             NaN              NaN            NaN
# 247       NaN     NaN             NaN              NaN            NaN
# 248       NaN     NaN             NaN              NaN            NaN
# 249       NaN     NaN             NaN              NaN            NaN
#
#     viewpoint_type_y  standardized_rating
# 0            frontal                1.000
# 1          side_back                1.000
# 2            frontal                0.775
# 3            frontal                0.100
# 4            frontal                0.550
# ..               ...                  ...
# 245              NaN                  NaN
# 246              NaN                  NaN
# 247              NaN                  NaN
# 248              NaN                  NaN
# 249              NaN                  NaN
#
# [250 rows x 17 columns]

# %% [markdown]
# Insight:
# 1. For user U037, the original ratings for P00524, P00522 is 5 (standardized is 1). So the predicted rating for all products with printed silver vest dress is 5. So it is understood that just category, pattern and color does not explain the reason for ratings. So to add more variance, we will add occlusion, viewpoint and zoom-in variables.

# %% [markdown]
# Adding occlusion, viewpoint and zoomin in CBF

# %%
#Step 4: Build product matrix on occlusion
occlusion_product = cbf_df[['product_id','occlusion_type']]
occlusion_product = occlusion_product.sort_values(by='product_id')

# %%
occlusion_product = occlusion_product.drop_duplicates(subset=['product_id','occlusion_type'], keep='first')

# %%
#As occlusion are strings, using TFIDF to convert them to usable values
tfidf = TfidfVectorizer()
tfidf_fit = tfidf.fit_transform(list(occlusion_product['occlusion_type']))

# %%
cols = tfidf.get_feature_names()
cols
# Out:
# ['heavy', 'medium', 'slight']

# %%
#Adding a small number (0.01) to avoid zeros
occlusion_prod_matrix = (pd.DataFrame(tfidf_fit.toarray().round(3), 
                                   index=[i for i in occlusion_product['product_id']], columns=cols))+0.01

# %%
occlusion_prod_matrix
# Out:
#         heavy  medium  slight
# P00003   0.01    0.01    1.01
# P00004   0.01    0.01    1.01
# P00005   0.01    0.01    1.01
# P00006   1.01    0.01    0.01
# P00007   0.01    0.01    1.01
# ...       ...     ...     ...
# P00712   0.01    0.01    1.01
# P00713   0.01    0.01    1.01
# P00714   0.01    0.01    1.01
# P00715   0.01    0.01    1.01
# P00716   0.01    0.01    1.01
#
# [250 rows x 3 columns]

# %%
#Step 4: Build product matrix on viewpoint
viewpoint_product = cbf_df[['product_id','viewpoint_type']]
viewpoint_product = viewpoint_product.sort_values(by='product_id')

# %%
viewpoint_product = viewpoint_product.drop_duplicates(subset=['product_id','viewpoint_type'], keep='first')

# %%
#As viewpoint are strings, using TFIDF to convert them to usable values
tfidf = TfidfVectorizer()
tfidf_fit = tfidf.fit_transform(list(viewpoint_product['viewpoint_type']))

# %%
cols = tfidf.get_feature_names()
cols
# Out:
# ['frontal', 'no', 'side_back']

# %%
#Adding a small number (0.01) to avoid zeros
viewpoint_prod_matrix = (pd.DataFrame(tfidf_fit.toarray().round(3), 
                                   index=[i for i in viewpoint_product['product_id']], columns=cols))+0.01

# %%
viewpoint_prod_matrix
# Out:
#         frontal    no  side_back
# P00003     0.01  1.01       0.01
# P00004     1.01  0.01       0.01
# P00005     0.01  1.01       0.01
# P00006     1.01  0.01       0.01
# P00007     0.01  1.01       0.01
# ...         ...   ...        ...
# P00712     0.01  0.01       1.01
# P00713     1.01  0.01       0.01
# P00714     1.01  0.01       0.01
# P00715     1.01  0.01       0.01
# P00716     1.01  0.01       0.01
#
# [250 rows x 3 columns]

# %%
#Step 5: Build product matrix on zoom-in
zoom_product = cbf_df[['product_id','zoom_in_type']]
zoom_product = zoom_product.sort_values(by='product_id')

# %%
zoom_product = zoom_product.drop_duplicates(subset=['product_id','zoom_in_type'], keep='first')

# %%
#As zoomin are strings, using TFIDF to convert them to usable values
tfidf = TfidfVectorizer()
tfidf_fit = tfidf.fit_transform(list(zoom_product['zoom_in_type']))

# %%
cols = tfidf.get_feature_names()
cols
# Out:
# ['heavy', 'medium', 'no']

# %%
#Adding a small number (0.01) to avoid zeros
zoom_prod_matrix = (pd.DataFrame(tfidf_fit.toarray().round(3), 
                                   index=[i for i in zoom_product['product_id']], columns=cols))+0.01

# %%
zoom_prod_matrix
# Out:
#         heavy  medium    no
# P00003   0.01    1.01  0.01
# P00004   0.01    1.01  0.01
# P00005   0.01    1.01  0.01
# P00006   0.01    1.01  0.01
# P00007   0.01    0.01  1.01
# ...       ...     ...   ...
# P00712   0.01    1.01  0.01
# P00713   0.01    0.01  1.01
# P00714   0.01    0.01  1.01
# P00715   0.01    0.01  1.01
# P00716   0.01    0.01  1.01
#
# [250 rows x 3 columns]

# %%
cosine_sim_matrix_occlusion = pd.DataFrame(cosine_similarity(occlusion_prod_matrix.values),
                                  columns=occlusion_product['product_id'],index=occlusion_product['product_id'])

# %%
cosine_sim_matrix_occlusion
# Out:
# product_id    P00003    P00004    P00005    P00006    P00007    P00008  \
# product_id
# P00003      1.000000  1.000000  1.000000  0.019896  1.000000  1.000000
# P00004      1.000000  1.000000  1.000000  0.019896  1.000000  1.000000
# P00005      1.000000  1.000000  1.000000  0.019896  1.000000  1.000000
# P00006      0.019896  0.019896  0.019896  1.000000  0.019896  0.019896
# P00007      1.000000  1.000000  1.000000  0.019896  1.000000  1.000000
# ...              ...       ...       ...       ...       ...       ...
# P00712      1.000000  1.000000  1.000000  0.019896  1.000000  1.000000
# P00004      1.000000  1.000000  1.000000  1.000000  ...  1.000000  0.019896
# P00005      1.000000  1.000000  1.000000  1.000000  ...  1.000000  0.019896
# P00006      1.000000  1.000000  1.000000  1.000000  ...  1.000000  0.019896
# P00007      0.019896  0.019896  0.019896  0.019896  ...  0.019896  1.000000
# ...              ...       ...       ...       ...  ...       ...       ...
# P00712      1.000000  1.000000  1.000000  1.000000  ...  1.000000  0.019896
# P00713      0.019896  0.019896  0.019896  0.019896  ...  0.019896  1.000000
# P00714      0.019896  0.019896  0.019896  0.019896  ...  0.019896  1.000000
# P00715      0.019896  0.019896  0.019896  0.019896  ...  0.019896  1.000000
# P00716      0.019896  0.019896  0.019896  0.019896  ...  0.019896  1.000000
#
# product_id    P00690    P00693    P00711    P00712    P00713    P00714  \
# product_id
# P00003      0.019896  1.000000  1.000000  1.000000  0.019896  0.019896
# P00004      0.019896  1.000000  1.000000  1.000000  0.019896  0.019896
# P00005      0.019896  1.000000  1.000000  1.000000  0.019896  0.019896
# P00006      0.019896  1.000000  1.000000  1.000000  0.019896  0.019896
# P00007      1.000000  0.019896  0.019896  0.019896  1.000000  1.000000
# ...              ...       ...       ...       ...       ...       ...
# P00712      0.019896  1.000000  1.000000  1.000000  0.019896  0.019896
# P00713      1.000000  0.019896  0.019896  0.019896  1.000000  1.000000
# P00714      1.000000  0.019896  0.019896  0.019896  1.000000  1.000000
# P00715      1.000000  0.019896  0.019896  0.019896  1.000000  1.000000
# P00716      1.000000  0.019896  0.019896  0.019896  1.000000  1.000000
#
# product_id    P00715    P00716
# product_id
# P00003      0.019896  0.019896
# P00004      0.019896  0.019896
# P00005      0.019896  0.019896
# P00006      0.019896  0.019896
# P00007      1.000000  1.000000
# ...              ...       ...
# P00712      0.019896  0.019896
# P00713      1.000000  1.000000
# P00714      1.000000  1.000000
# P00715      1.000000  1.000000
# P00716      1.000000  1.000000
#
# [250 rows x 250 columns]

# %%
final_similarity_matrix_extraattr = final_similarity_matrix.multiply(cosine_sim_matrix_occlusion).multiply(cosine_sim_matrix_viewpoint).multiply(cosine_sim_matrix_zoom)

# %%
#Predicting ratings based on all attributes

weighted_ratings_extraattr = user_prod_matrix.dot(final_similarity_matrix_extraattr)

# %%
#Standardizing the weighted ratings

min_max = MinMaxScaler(feature_range = (0.1,1))
min_max.fit(weighted_ratings_extraattr.values)
weighted_ratings_extraattr = min_max.transform(weighted_ratings_extraattr.values)

# %%
weighted_ratings_extraattr
# Out:
# array([[0.10598532, 0.11278491, 0.11768249, ..., 0.60153473, 0.54611522,
#         0.63227042],
#        [0.32773952, 0.10067535, 0.10700397, ..., 0.1002317 , 0.10606993,
#         0.10162541],
#        [0.10101426, 0.10090828, 0.100376  , ..., 0.10802717, 0.33383121,
#         0.12070768],
#        ...,
#        [0.32842861, 0.47615425, 0.13121766, ..., 0.43031547, 0.48075194,
#         0.1438119 ],
#        [0.10036156, 0.10029068, 0.10001667, ..., 0.10017151, 0.10606442,
#         0.10089156],
#        [0.76023603, 0.81481572, 0.15824091, ..., 0.51190365, 0.41523173,
#         0.12052946]])

# %%
#Convert this array back to matrix form
weighted_ratings_extraattrdf = pd.DataFrame(weighted_ratings_extraattr,index=sorted(cbf_df['user_id'].unique()),
                                columns=sorted(cbf_df['product_id'].unique()))

# %%
# test = pd.melt(weighted_ratings, id_vars=sorted(cbf_df['user_id'].unique()),
#                                                 value_vars=sorted(cbf_df['product_id'].unique()))
weighted_ratings_extraattrdf = weighted_ratings_extraattrdf.stack().reset_index()

# %%
weighted_ratings_extraattrdf = weighted_ratings_extraattrdf.rename(columns={'level_0':'user_id','level_1':'product_id',
                                                  0:'predicted_rating'})

# %%
weighted_ratings_extraattrdf
# Out:
#       user_id product_id  predicted_rating
# 0        U001     P00003          0.105985
# 1        U001     P00004          0.112785
# 2        U001     P00005          0.117682
# 3        U001     P00006          0.115225
# 4        U001     P00007          0.817410
# ...       ...        ...               ...
# 24995    U100     P00712          0.115742
# 24996    U100     P00713          0.511904
# 24997    U100     P00714          0.511904
# 24998    U100     P00715          0.415232
# 24999    U100     P00716          0.120529
#
# [25000 rows x 3 columns]

# %%
prod_attr_1 = weighted_ratings_extraattrdf.merge(product_prop,on=['product_id'],how='left')

# %%
prod_attr_1.sort_values(by=['predicted_rating'], inplace=True,ascending=False)

# %%
prod_attr_1
# Out:
#       user_id product_id  predicted_rating  pattern     color  \
# 11006    U045     P00009               1.0    plain  Charcoal
# 2824     U012     P00227               1.0    plain      Gray
# 9788     U040     P00152               1.0    plain      Gray
# 15956    U064     P00512               1.0  printed      Gray
# 18837    U076     P00250               1.0  printed      Gray
# ...       ...        ...               ...      ...       ...
# 16483    U066     P00607               0.1    plain  Charcoal
# 18692    U075     P00475               0.1    plain      Gray
# 18691    U075     P00473               0.1    plain       Tan
# 18690    U075     P00467               0.1    plain  Charcoal
# 18559    U075     P00173               0.1  printed    Silver
#
#            category_name occlusion_type zoom_in_type viewpoint_type
# 11006    long_sleeve_top         medium       medium        frontal
# 2824   long_sleeve_dress         medium       medium        frontal
# 9788          vest_dress         slight       medium             no
# 15956         vest_dress         slight       medium        frontal
# 18837    long_sleeve_top         slight       medium      side_back
# ...                  ...            ...          ...            ...
# 16483             shorts         slight       medium             no
# 18692           trousers         slight       medium        frontal
# 18691           trousers         medium           no        frontal
# 18690           trousers         slight           no        frontal
# 18559         vest_dress          heavy           no        frontal
#
# [25000 rows x 9 columns]

# %%
user_037_pred_1 = prod_attr_1[prod_attr_1['user_id']=="U037"]

# %%
user_037_act_1 = cbf_df[cbf_df['user_id']=="U037"]

# %%
u037_merged_1 = user_037_pred_1.merge(user_037_act_1,how='left',on=['user_id','product_id'])

# %%
#The predicted_rating is standardized (between 0 and 1). standardized_rating is the standardized version 
#of product_reviews column. Note that if the product_reviews column is NaN, that means the user did not provide rating
#for that product. predicted_rating provides the corresponding rating that the user can possibly provide
u037_merged_1
# Out:
#     user_id product_id  predicted_rating pattern_x color_x  \
# 0      U037     P00524          1.000000   printed  Silver
# 1      U037     P00522          1.000000   printed  Silver
# 2      U037     P00160          0.996370   printed   Brown
# 3      U037     P00097          0.987964     plain    Gray
# 4      U037     P00099          0.987964     plain    Gray
# ..      ...        ...               ...       ...     ...
# 245    U037     P00307          0.100221     plain  Silver
# 246    U037     P00301          0.100221     plain  Silver
# 247    U037     P00302          0.100221     plain  Silver
# 248    U037     P00598          0.100152   printed    Gray
# 249    U037     P00587          0.100152   printed    Gray
#
#          category_name_x occlusion_type_x zoom_in_type_x viewpoint_type_x  \
# 0             vest_dress           medium         medium          frontal
# 1             vest_dress           medium         medium        side_back
# 2             vest_dress           medium             no          frontal
# 3    long_sleeve_outwear           medium         medium          frontal
# 4    long_sleeve_outwear           medium         medium          frontal
# ..                   ...              ...            ...              ...
# 245     short_sleeve_top           slight          heavy               no
# 246     short_sleeve_top           slight          heavy               no
# 247     short_sleeve_top           slight          heavy               no
# 248      long_sleeve_top            heavy             no        side_back
# 249      long_sleeve_top            heavy             no        side_back
#
#     product_reviews pattern_y color_y      category_name_y occlusion_type_y  \
# 0                 5   printed  Silver           vest_dress           medium
# 1                 5   printed  Silver           vest_dress           medium
# 2                 4   printed   Brown           vest_dress           medium
# 3                 5     plain    Gray  long_sleeve_outwear           medium
# 4                 4     plain    Gray  long_sleeve_outwear           medium
# ..              ...       ...     ...                  ...              ...
# 245             NaN       NaN     NaN                  NaN              NaN
# 246             NaN       NaN     NaN                  NaN              NaN
# 247             NaN       NaN     NaN                  NaN              NaN
# 248             NaN       NaN     NaN                  NaN              NaN
# 249             NaN       NaN     NaN                  NaN              NaN
#
#     zoom_in_type_y viewpoint_type_y  standardized_rating
# 0           medium          frontal                1.000
# 1           medium        side_back                1.000
# 2               no          frontal                0.775
# 3           medium          frontal                1.000
# 4           medium          frontal                0.775
# ..             ...              ...                  ...
# 245            NaN              NaN                  NaN
# 246            NaN              NaN                  NaN
# 247            NaN              NaN                  NaN
# 248            NaN              NaN                  NaN
# 249            NaN              NaN                  NaN
#
# [250 rows x 17 columns]

# %%
#Products with 5 top reviews that can be recommended to U037
u037_merged_1[pd.isnull(u037_merged_1['product_reviews'])].head(5)
# Out:
#    user_id product_id  predicted_rating pattern_x color_x     category_name_x  \
# 12    U037     P00197          0.739081   printed    Gray    short_sleeve_top
# 19    U037     P00425          0.571904     plain  Silver  short_sleeve_dress
# 22    U037     P00257          0.501385     plain  Silver   long_sleeve_dress
# 23    U037     P00276          0.501385     plain  Silver   long_sleeve_dress
# 24    U037     P00273          0.501385     plain  Silver   long_sleeve_dress
#
#    occlusion_type_x zoom_in_type_x viewpoint_type_x product_reviews pattern_y  \
# 12           slight          heavy               no             NaN       NaN
# 19           medium             no          frontal             NaN       NaN
# 22           medium             no          frontal             NaN       NaN
# 23           medium             no          frontal             NaN       NaN
# 24           medium             no          frontal             NaN       NaN
#
#    color_y category_name_y occlusion_type_y zoom_in_type_y viewpoint_type_y  \
# 12     NaN             NaN              NaN            NaN              NaN
# 19     NaN             NaN              NaN            NaN              NaN
# 22     NaN             NaN              NaN            NaN              NaN
# 23     NaN             NaN              NaN            NaN              NaN
# 24     NaN             NaN              NaN            NaN              NaN
#
#     standardized_rating
# 12                  NaN
# 19                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
